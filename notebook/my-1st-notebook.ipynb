# %%
import numpy as np

# Create a NumPy array with shape (10, 3) filled with random integers between 0 and 100
array = np.random.randint(0, 100, size=(10, 3))

# Print the array
print("Array:")
print(array)

# Visualize the array
import matplotlib.pyplot as plt

plt.imshow(array, cmap='viridis', interpolation='nearest')
plt.colorbar(label='Value')
plt.title('Random Integer Array (10x3)')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()
# Out:
# Array:
# [[26 19 29]
#  [75 80 68]
#  [66  4 61]
#  [58 57 99]
#  [ 3 30 17]
#  [63 64 78]
#  [46 66 73]
#  [70 44 95]
#  [38 12 99]
#  [22 87 97]]
