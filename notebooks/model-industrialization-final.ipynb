# %%
import sys
sys.path.append('C:/Users/Bhargav/dsp-bhargav-ravi')
import pandas as pd
from house_prices.train import build_model

training_data_df = pd.read_csv('train.csv')
model_performance_dict = build_model(training_data_df)
print(model_performance_dict)
# Out:
# {'rmse': 0.24}

# %%
# Model inference
import pandas as pd
from house_prices.inference import make_predictions

user_data_df = pd.read_csv('test.csv')
predictions = make_predictions(user_data_df)
print(predictions)
# Out:
# [152370.80467766 152959.990287   198033.80315601 ... 155866.77850004
#  174304.28024307 174197.56207823]
